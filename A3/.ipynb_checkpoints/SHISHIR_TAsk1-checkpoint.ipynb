# %%
import time
import math
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2

from sklearn.metrics import confusion_matrix
from datetime import timedelta
import os

# %matplotlib inline

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="-1" #for training on gpu/cpu

# %%
data_path="data.npy"
target_path="target.npy"
task=1

# %% [markdown]
# ### LOAD DATA

# %%
def data_segmentation(data_path, target_path, task):
    # task = 0 >> select the name ID targets for face recognition task
    # task = 1 >> select the gender ID targets for gender recognition task
    data = np.load(data_path)/255
    data = np.reshape(data, [-1, 32*32])
    target = np.load(target_path)
    np.random.seed(45689)
    rnd_idx = np.arange(np.shape(data)[0])
    np.random.shuffle(rnd_idx)
    trBatch = int(0.8*len(rnd_idx))
    validBatch = int(0.1*len(rnd_idx))
    trainData, validData, testData = data[rnd_idx[1:trBatch],:], \
                                    data[rnd_idx[trBatch+1:trBatch + validBatch],:],\
                                    data[rnd_idx[trBatch + validBatch+1:-1],:]
    trainTarget, validTarget, testTarget = target[rnd_idx[1:trBatch], task], \
                                            target[rnd_idx[trBatch+1:trBatch + validBatch], task],\
                                            target[rnd_idx[trBatch + validBatch + 1:-1], task]
    return trainData, validData, testData, trainTarget, validTarget, testTarget

# %%
trainData, validData, testData, trainTarget, validTarget, testTarget=data_segmentation(data_path, target_path, task)

# %% [raw]
# ### The gender of the actors: ‘Male’ and ‘Female’ are encoded as ‘0’ and ‘1’, respectively

# %%
class_names = ["Male","Female"]

fig=plt.figure(figsize=(10, 10))
columns = 5
rows = 5
for i in range(1, columns*rows +1):
    img = trainData[i-1]*255
    ax1 = fig.add_subplot(rows, columns, i)
    ax1.set_title(class_names[trainTarget[i-1]])
    ax1.get_xaxis().set_visible(False)
    ax1.get_yaxis().set_visible(False)
    plt.imshow(img.reshape((32, 32)), cmap='gray')
    plt.grid
plt.show()


print(trainTarget[1])
# Out:
# 1

# %% [markdown]
# ### You are provided withtwo .npy files which have 936 rows of images and labels, and you should divide the dataset into 80/10/10% for training, validation and test, respectively.

# %%
print("- Training-set:\t\t{}".format(len(trainData)))
print("- Test-set:\t\t{}".format(len(testData)))
print("- Validation-set:\t{}".format(len(validData)))
# Out:
# - Training-set:		747
# - Test-set:		93
# - Validation-set:	92

# %% [markdown]
# ### Distribution
#
# Michael Vartan has biased data. Data is unbalanced.

# %%
a = trainTarget
plt.style.use('ggplot')
plt.hist(a, bins = [0,1,2,3,4,5]) 
plt.title("histogram") 
plt.show()

# %% [markdown]
# ### One-HOT

# %%
b = np.zeros((trainTarget.size, trainTarget.max()+1))
b[np.arange(trainTarget.size),trainTarget] = 1
trainLabel=b
print ('Training set', trainLabel.shape)
# Out:
# Training set (747, 2)

# %%
b = np.zeros((validTarget.size, validTarget.max()+1))
b[np.arange(validTarget.size),validTarget] = 1
validLabel=b
print ('Training set', validLabel.shape)
# Out:
# Training set (92, 2)

# %%
b = np.zeros((testTarget.size, testTarget.max()+1))
b[np.arange(testTarget.size),testTarget] = 1
testLabel=b
print ('Training set', testLabel.shape)
# Out:
# Training set (93, 2)

# %%
plt.figure(figsize=[5,5])

# Display the first image in training data
plt.subplot(121)
curr_img = np.reshape(trainData[0], (32,32))
curr_lbl = np.argmax(trainLabel[0,:])
plt.imshow(curr_img, cmap='gray')
plt.title("(Label: " + str(class_names[curr_lbl]) + ")")

# Display the first image in testing data
plt.subplot(122)
curr_img = np.reshape(testData[0], (32,32))
curr_lbl = np.argmax(testLabel[0,:])
plt.imshow(curr_img, cmap='gray')
plt.title("(Label: " + str(class_names[curr_lbl]) + ")")
# Out:
# Text(0.5, 1.0, '(Label: Female)')

# %% [markdown]
# #### MODEL TRAIN  TASK-0
# learning_rate = 0.001
# num_steps = 2000
# batch_size = 32

# %%
# Training Parameters
learning_rate = 0.001
num_steps = 2000
batch_size = 32

# Network Parameters
num_input = 1024 
num_classes = 6 
dropout = 0.5 # Dropout, probability to drop a unit


# Create the neural network
def conv_net(x_dict, n_classes, dropout, reuse, is_training):
    # Define a scope for reusing the variables
    with tf.variable_scope('ConvNet', reuse=reuse):

        # Data input is a 1-D vector of 1024 features (32*32 pixels)
        # Reshape to match picture format [Height x Width x Channel]
        # Tensor input become 4-D: [Batch Size, Height, Width, Channel]
        x = tf.reshape(x_dict, shape=[-1, 32, 32, 1])

        # Convolution Layer with 32 filters and a kernel size of 5
        conv1 = tf.layers.conv2d(x, 32, 5, activation=tf.nn.relu)
        # Max Pooling (down-sampling) with strides of 2 and kernel size of 3
        conv1 = tf.layers.max_pooling2d(conv1, 3, 2)


        # Flatten the data to a 1-D vector for the fully connected layer
        fc1 = tf.contrib.layers.flatten(conv1)

        # Fully connected layer (in tf contrib folder for now)
        fc1 = tf.layers.dense(fc1, 384)
        
        # Fully connected layer (in tf contrib folder for now)
        fc2 = tf.layers.dense(fc1, 192)
        
        
        # Apply Dropout (if is_training is False, dropout is not applied)
        fc3 = tf.layers.dropout(fc2, rate=dropout, training=is_training)

        # Output layer, class prediction
        out = tf.layers.dense(fc3, n_classes)

    return out


# Define the model function (following TF Estimator Template)
def model_fn(features, labels, mode):
    
    # Build the neural network
    # Because Dropout have different behavior at training and prediction time, we
    # need to create 2 distinct computation graphs that still share the same weights.
    logits_train = conv_net(features, num_classes, dropout, reuse=False,
                            is_training=True)
    logits_test = conv_net(features, num_classes, dropout, reuse=True,
                           is_training=False)

    # Predictions
    pred_classes = tf.argmax(logits_test, axis=1)
    pred_probas = tf.nn.softmax(logits_test)

    # If prediction mode, early return
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=pred_classes)

        # Define loss and optimizer
    loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
        logits=logits_train, labels=tf.cast(labels, dtype=tf.int32)))
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    train_op = optimizer.minimize(loss_op,
                                  global_step=tf.train.get_global_step())

    # Evaluate the accuracy of the model
    acc_op = tf.metrics.accuracy(labels=labels, predictions=pred_classes)

    # TF Estimators requires to return a EstimatorSpec, that specify
    # the different ops for training, evaluating, ...
    estim_specs = tf.estimator.EstimatorSpec(
        mode=mode,
        predictions=pred_classes,
        loss=loss_op,
        train_op=train_op,
        eval_metric_ops={'accuracy': acc_op})

    return estim_specs

# Build the Estimator
model = tf.estimator.Estimator(model_fn)

# Define the input function for training
input_fn = tf.estimator.inputs.numpy_input_fn(
    x=trainData, y=trainTarget,
    batch_size=batch_size, num_epochs=50, shuffle=True)

# Define the input function for validation
valid_fn = tf.estimator.inputs.numpy_input_fn(
    x=validData, y=validTarget,
    batch_size=batch_size, num_epochs=50, shuffle=True)

# Train the Model
classifier = tf.estimator.Estimator(
    model_fn=model_fn,)

train_spec = tf.estimator.TrainSpec(
    input_fn = input_fn,
)

eval_spec = tf.estimator.EvalSpec(
    input_fn = valid_fn,
    throttle_secs=120,
    start_delay_secs=120,
)

tf.estimator.train_and_evaluate(
    classifier,
    train_spec,
    eval_spec
)


# Evaluate the Model
# Define the input function for evaluating
input_fn = tf.estimator.inputs.numpy_input_fn(
    x=testData, y=testTarget,
    batch_size=batch_size, shuffle=False)
# Use the Estimator 'evaluate' method
e = model.evaluate(input_fn)

print("Testing Accuracy:", e['accuracy'])
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\zorinDM\AppData\Local\Temp\tmplurzrpjb
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\zorinDM\\AppData\\Local\\Temp\\tmplurzrpjb', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020EC5B19780>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\zorinDM\AppData\Local\Temp\tmp5hqpifi6
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\zorinDM\\AppData\\Local\\Temp\\tmp5hqpifi6', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020EC5B197F0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# WARNING:tensorflow:From F:\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From F:\Anaconda\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From F:\Anaconda\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From <ipython-input-13-5521fbc17010>:23: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv2d instead.
# WARNING:tensorflow:From <ipython-input-13-5521fbc17010>:25: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.max_pooling2d instead.
# F:\Anaconda\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From F:\Anaconda\lib\site-packages\tensorflow\contrib\layers\python\layers\layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-13-5521fbc17010>:32: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From <ipython-input-13-5521fbc17010>:39: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From F:\Anaconda\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From F:\Anaconda\lib\site-packages\tensorflow\python\ops\metrics_impl.py:455: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From F:\Anaconda\lib\site-packages\tensorflow\python\training\monitored_session.py:809: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\zorinDM\AppData\Local\Temp\tmp5hqpifi6\model.ckpt.
# INFO:tensorflow:loss = 1.7287928565785755, step = 1
# INFO:tensorflow:global_step/sec: 15.8138
# INFO:tensorflow:loss = 0.15176164903631337, step = 101 (6.326 sec)
# INFO:tensorflow:global_step/sec: 16.2205
# INFO:tensorflow:loss = 0.009519311842373064, step = 201 (6.164 sec)
# INFO:tensorflow:global_step/sec: 16.0231
# INFO:tensorflow:loss = 0.04810765237676474, step = 301 (6.242 sec)
# INFO:tensorflow:global_step/sec: 16.2574
# INFO:tensorflow:loss = 0.0007600320413266584, step = 401 (6.151 sec)
# INFO:tensorflow:global_step/sec: 15.706
# INFO:tensorflow:loss = 0.00033902186242455945, step = 501 (6.367 sec)
# INFO:tensorflow:global_step/sec: 16.0681
# INFO:tensorflow:loss = 0.00032319812692032735, step = 601 (6.223 sec)
# INFO:tensorflow:global_step/sec: 16.1096
# INFO:tensorflow:loss = 8.678336645458583e-05, step = 701 (6.207 sec)
# INFO:tensorflow:global_step/sec: 15.9744
# INFO:tensorflow:loss = 0.0005530717419223549, step = 801 (6.260 sec)
# INFO:tensorflow:global_step/sec: 15.3468
# INFO:tensorflow:loss = 0.00017566878585565843, step = 901 (6.516 sec)
# INFO:tensorflow:global_step/sec: 16.0051
# INFO:tensorflow:loss = 0.0016019605539028094, step = 1001 (6.249 sec)
# INFO:tensorflow:global_step/sec: 15.4369
# INFO:tensorflow:loss = 0.0002361810513179286, step = 1101 (6.477 sec)
# INFO:tensorflow:Saving checkpoints for 1168 into C:\Users\zorinDM\AppData\Local\Temp\tmp5hqpifi6\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-02T09:33:47Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From F:\Anaconda\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from C:\Users\zorinDM\AppData\Local\Temp\tmp5hqpifi6\model.ckpt-1168
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-02-09:33:50
# INFO:tensorflow:Saving dict for global step 1168: accuracy = 1.0, global_step = 1168, loss = 0.004636893
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1168: C:\Users\zorinDM\AppData\Local\Temp\tmp5hqpifi6\model.ckpt-1168
# INFO:tensorflow:Loss for final step: 5.0617542495663585e-05.
# INFO:tensorflow:Could not find trained model in model_dir: C:\Users\zorinDM\AppData\Local\Temp\tmplurzrpjb, running initialization to evaluate.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-02T09:33:50Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-02-09:33:51
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.29032257, global_step = 0, loss = 1.7857584
# Testing Accuracy: 0.29032257

# %% [markdown]
# #### MODEL TRAIN  TASK-0
# learning_rate = 0.0001
# num_steps = 2000
# batch_size = 32

# %%
# Training Parameters
learning_rate = 0.0001
num_steps = 2000
batch_size = 32


# Build the Estimator
model = tf.estimator.Estimator(model_fn)

# Define the input function for training
input_fn = tf.estimator.inputs.numpy_input_fn(
    x=trainData, y=trainTarget,
    batch_size=batch_size, num_epochs=50, shuffle=True)

# Define the input function for validation
valid_fn = tf.estimator.inputs.numpy_input_fn(
    x=validData, y=validTarget,
    batch_size=batch_size, num_epochs=50, shuffle=True)

# Train the Model
classifier = tf.estimator.Estimator(
    model_fn=model_fn,)

train_spec = tf.estimator.TrainSpec(
    input_fn = input_fn,
)

eval_spec = tf.estimator.EvalSpec(
    input_fn = valid_fn,
    throttle_secs=120,
    start_delay_secs=120,
)

tf.estimator.train_and_evaluate(
    classifier,
    train_spec,
    eval_spec
)


# Evaluate the Model
# Define the input function for evaluating
input_fn = tf.estimator.inputs.numpy_input_fn(
    x=testData, y=testTarget,
    batch_size=batch_size, shuffle=False)
# Use the Estimator 'evaluate' method
e = model.evaluate(input_fn)

print("Testing Accuracy:", e['accuracy'])
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\zorinDM\AppData\Local\Temp\tmpp4y2v_7q
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\zorinDM\\AppData\\Local\\Temp\\tmpp4y2v_7q', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020EC5B04AC8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\zorinDM\AppData\Local\Temp\tmpv7z_zkdk
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\zorinDM\\AppData\\Local\\Temp\\tmpv7z_zkdk', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020EC5B04400>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\zorinDM\AppData\Local\Temp\tmpv7z_zkdk\model.ckpt.
# INFO:tensorflow:loss = 1.8744723641735621, step = 1
# INFO:tensorflow:global_step/sec: 15.787
# INFO:tensorflow:loss = 0.3024817749953995, step = 101 (6.336 sec)
# INFO:tensorflow:global_step/sec: 15.6883
# INFO:tensorflow:loss = 0.11642912774148548, step = 201 (6.373 sec)
# INFO:tensorflow:global_step/sec: 15.8479
# INFO:tensorflow:loss = 0.28779562813708265, step = 301 (6.310 sec)
# INFO:tensorflow:global_step/sec: 15.8378
# INFO:tensorflow:loss = 0.05867214973525664, step = 401 (6.315 sec)
# INFO:tensorflow:global_step/sec: 15.9489
# INFO:tensorflow:loss = 0.04527331965545353, step = 501 (6.270 sec)
# INFO:tensorflow:global_step/sec: 16.0205
# INFO:tensorflow:loss = 0.07564622762362505, step = 601 (6.242 sec)
# INFO:tensorflow:global_step/sec: 15.9058
# INFO:tensorflow:loss = 0.007203181154175984, step = 701 (6.287 sec)
# INFO:tensorflow:global_step/sec: 16.0875
# INFO:tensorflow:loss = 0.01431201317312659, step = 801 (6.216 sec)
# INFO:tensorflow:global_step/sec: 15.9898
# INFO:tensorflow:loss = 0.00859850512418233, step = 901 (6.254 sec)
# INFO:tensorflow:global_step/sec: 15.8329
# INFO:tensorflow:loss = 0.011732558518041274, step = 1001 (6.316 sec)
# INFO:tensorflow:global_step/sec: 15.2741
# INFO:tensorflow:loss = 0.003793932885145907, step = 1101 (6.546 sec)
# INFO:tensorflow:Saving checkpoints for 1168 into C:\Users\zorinDM\AppData\Local\Temp\tmpv7z_zkdk\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-02T09:35:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zorinDM\AppData\Local\Temp\tmpv7z_zkdk\model.ckpt-1168
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-02-09:35:10
# INFO:tensorflow:Saving dict for global step 1168: accuracy = 1.0, global_step = 1168, loss = 0.017854257
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1168: C:\Users\zorinDM\AppData\Local\Temp\tmpv7z_zkdk\model.ckpt-1168
# INFO:tensorflow:Loss for final step: 0.0006828781646313118.
# INFO:tensorflow:Could not find trained model in model_dir: C:\Users\zorinDM\AppData\Local\Temp\tmpp4y2v_7q, running initialization to evaluate.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-02T09:35:11Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-02-09:35:12
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.0, global_step = 0, loss = 1.865798
# Testing Accuracy: 0.0

# %% [markdown]
# #### MODEL TRAIN  TASK-0
# learning_rate = 0.001
# num_steps = 5000
# batch_size = 32

# %%
# Training Parameters
learning_rate = 0.0001
num_steps = 5000
batch_size = 32

# Build the Estimator
model = tf.estimator.Estimator(model_fn)

# Define the input function for training
input_fn = tf.estimator.inputs.numpy_input_fn(
    x=trainData, y=trainTarget,
    batch_size=batch_size, num_epochs=50, shuffle=True)

# Define the input function for validation
valid_fn = tf.estimator.inputs.numpy_input_fn(
    x=validData, y=validTarget,
    batch_size=batch_size, num_epochs=50, shuffle=True)

# Train the Model
classifier = tf.estimator.Estimator(
    model_fn=model_fn,)

train_spec = tf.estimator.TrainSpec(
    input_fn = input_fn,
)

eval_spec = tf.estimator.EvalSpec(
    input_fn = valid_fn,
    throttle_secs=120,
    start_delay_secs=120,
)

tf.estimator.train_and_evaluate(
    classifier,
    train_spec,
    eval_spec
)


# Evaluate the Model
# Define the input function for evaluating
input_fn = tf.estimator.inputs.numpy_input_fn(
    x=testData, y=testTarget,
    batch_size=batch_size, shuffle=False)
# Use the Estimator 'evaluate' method
e = model.evaluate(input_fn)

print("Testing Accuracy:", e['accuracy'])
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\zorinDM\AppData\Local\Temp\tmp4dj1m7xk
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\zorinDM\\AppData\\Local\\Temp\\tmp4dj1m7xk', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020EC7EE73C8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\zorinDM\AppData\Local\Temp\tmp3uvwpvip
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\zorinDM\\AppData\\Local\\Temp\\tmp3uvwpvip', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020EC7EE79E8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\zorinDM\AppData\Local\Temp\tmp3uvwpvip\model.ckpt.
# INFO:tensorflow:loss = 1.868612995491092, step = 1
# INFO:tensorflow:global_step/sec: 15.9512
# INFO:tensorflow:loss = 0.33548867913897534, step = 101 (6.270 sec)
# INFO:tensorflow:global_step/sec: 16.0485
# INFO:tensorflow:loss = 0.2301795298117535, step = 201 (6.230 sec)
# INFO:tensorflow:global_step/sec: 16.1341
# INFO:tensorflow:loss = 0.15046144611731901, step = 301 (6.198 sec)
# INFO:tensorflow:global_step/sec: 15.916
# INFO:tensorflow:loss = 0.05496660271619706, step = 401 (6.284 sec)
# INFO:tensorflow:global_step/sec: 15.1538
# INFO:tensorflow:loss = 0.05038818937952258, step = 501 (6.599 sec)
# INFO:tensorflow:global_step/sec: 15.1263
# INFO:tensorflow:loss = 0.011111169546913163, step = 601 (6.611 sec)
# INFO:tensorflow:global_step/sec: 15.7875
# INFO:tensorflow:loss = 0.011521627690740771, step = 701 (6.334 sec)
# INFO:tensorflow:global_step/sec: 15.788
# INFO:tensorflow:loss = 0.01337805796494937, step = 801 (6.335 sec)
# INFO:tensorflow:global_step/sec: 15.53
# INFO:tensorflow:loss = 0.006997994063399819, step = 901 (6.437 sec)
# INFO:tensorflow:global_step/sec: 15.9265
# INFO:tensorflow:loss = 0.01061168812018052, step = 1001 (6.280 sec)
# INFO:tensorflow:global_step/sec: 15.9411
# INFO:tensorflow:loss = 0.0044688321146627, step = 1101 (6.273 sec)
# INFO:tensorflow:Saving checkpoints for 1168 into C:\Users\zorinDM\AppData\Local\Temp\tmp3uvwpvip\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-02T09:36:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zorinDM\AppData\Local\Temp\tmp3uvwpvip\model.ckpt-1168
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2019-12-02-09:36:31
# INFO:tensorflow:Saving dict for global step 1168: accuracy = 0.9890625, global_step = 1168, loss = 0.023579072
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1168: C:\Users\zorinDM\AppData\Local\Temp\tmp3uvwpvip\model.ckpt-1168
# INFO:tensorflow:Loss for final step: 0.004728370019875158.
# INFO:tensorflow:Could not find trained model in model_dir: C:\Users\zorinDM\AppData\Local\Temp\tmp4dj1m7xk, running initialization to evaluate.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-02T09:36:31Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-02-09:36:32
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.010752688, global_step = 0, loss = 1.8237767
# Testing Accuracy: 0.010752688

# %% [markdown]
# #### MODEL TRAIN  TASK-0
# learning_rate = 0.001
# num_steps = 5000
# batch_size = 32

# %%
# Training Parameters
learning_rate = 0.001
num_steps = 2000
batch_size = 128

# Build the Estimator
model = tf.estimator.Estimator(model_fn)

# Define the input function for training
input_fn = tf.estimator.inputs.numpy_input_fn(
    x=trainData, y=trainTarget,
    batch_size=batch_size, num_epochs=50, shuffle=True)

# Define the input function for validation
valid_fn = tf.estimator.inputs.numpy_input_fn(
    x=validData, y=validTarget,
    batch_size=batch_size, num_epochs=50, shuffle=True)

# Train the Model
classifier = tf.estimator.Estimator(
    model_fn=model_fn,)

train_spec = tf.estimator.TrainSpec(
    input_fn = input_fn,
)

eval_spec = tf.estimator.EvalSpec(
    input_fn = valid_fn,
    throttle_secs=120,
    start_delay_secs=120,
)

tf.estimator.train_and_evaluate(
    classifier,
    train_spec,
    eval_spec
)


# Evaluate the Model
# Define the input function for evaluating
input_fn = tf.estimator.inputs.numpy_input_fn(
    x=testData, y=testTarget,
    batch_size=batch_size, shuffle=False)
# Use the Estimator 'evaluate' method
e = model.evaluate(input_fn)

print("Testing Accuracy:", e['accuracy'])
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\zorinDM\AppData\Local\Temp\tmphxury52h
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\zorinDM\\AppData\\Local\\Temp\\tmphxury52h', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020EC8B89780>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\zorinDM\AppData\Local\Temp\tmpb5yyau54
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\zorinDM\\AppData\\Local\\Temp\\tmpb5yyau54', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020EC8B89390>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\zorinDM\AppData\Local\Temp\tmpb5yyau54\model.ckpt.
# INFO:tensorflow:loss = 2.1629622002579714, step = 1
# INFO:tensorflow:global_step/sec: 6.06241
# INFO:tensorflow:loss = 0.04918054902821763, step = 101 (16.497 sec)
# INFO:tensorflow:global_step/sec: 6.11134
# INFO:tensorflow:loss = 0.007394738007177393, step = 201 (16.364 sec)
# INFO:tensorflow:Saving checkpoints for 292 into C:\Users\zorinDM\AppData\Local\Temp\tmpb5yyau54\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-02T09:37:22Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zorinDM\AppData\Local\Temp\tmpb5yyau54\model.ckpt-292
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Finished evaluation at 2019-12-02-09:37:25
# INFO:tensorflow:Saving dict for global step 292: accuracy = 1.0, global_step = 292, loss = 0.012485357
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 292: C:\Users\zorinDM\AppData\Local\Temp\tmpb5yyau54\model.ckpt-292
# INFO:tensorflow:Loss for final step: 0.0043457289462508625.
# INFO:tensorflow:Could not find trained model in model_dir: C:\Users\zorinDM\AppData\Local\Temp\tmphxury52h, running initialization to evaluate.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-02T09:37:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-02-09:37:26
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.0, global_step = 0, loss = 2.059852
# Testing Accuracy: 0.0

# %% [markdown]
# #### MODEL TRAIN  TASK-0
# learning_rate = 0.01
# num_steps = 1000
# batch_size = 200
# dropout = 0.5

# %%
# Training Parameters
learning_rate = 0.001
num_steps = 1000
batch_size = 200

# Network Parameters
num_input = 1024 
num_classes = 6 
dropout = 0.5 


# Create the neural network
def conv_net(x_dict, n_classes, dropout, reuse, is_training):
    # Define a scope for reusing the variables
    with tf.variable_scope('ConvNet', reuse=reuse):

        # Data input is a 1-D vector of 1024 features (32*32 pixels)
        # Reshape to match picture format [Height x Width x Channel]
        # Tensor input become 4-D: [Batch Size, Height, Width, Channel]
        x = tf.reshape(x_dict, shape=[-1, 32, 32, 1])

        # Convolution Layer with 32 filters and a kernel size of 5
        conv1 = tf.layers.conv2d(x, 32, 5, activation=tf.nn.relu)
        # Max Pooling (down-sampling) with strides of 2 and kernel size of 3
        conv1 = tf.layers.max_pooling2d(conv1, 3, 2)


        # Flatten the data to a 1-D vector for the fully connected layer
        fc1 = tf.contrib.layers.flatten(conv1)

        # Fully connected layer (in tf contrib folder for now)
        fc1 = tf.layers.dense(fc1, 384)
        
        # Fully connected layer (in tf contrib folder for now)
        fc2 = tf.layers.dense(fc1, 192)
        
        
        # Apply Dropout (if is_training is False, dropout is not applied)
        fc3 = tf.layers.dropout(fc2, rate=dropout, training=is_training)

        # Output layer, class prediction
        out = tf.layers.dense(fc3, n_classes)

    return out


# Define the model function (following TF Estimator Template)
def model_fn(features, labels, mode):
    
    # Build the neural network
    # Because Dropout have different behavior at training and prediction time, we
    # need to create 2 distinct computation graphs that still share the same weights.
    logits_train = conv_net(features, num_classes, dropout, reuse=False,
                            is_training=True)
    logits_test = conv_net(features, num_classes, dropout, reuse=True,
                           is_training=False)

    # Predictions
    pred_classes = tf.argmax(logits_test, axis=1)
    pred_probas = tf.nn.softmax(logits_test)

    # If prediction mode, early return
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=pred_classes)

        # Define loss and optimizer
    loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
        logits=logits_train, labels=tf.cast(labels, dtype=tf.int32)))
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    train_op = optimizer.minimize(loss_op,
                                  global_step=tf.train.get_global_step())

    # Evaluate the accuracy of the model
    acc_op = tf.metrics.accuracy(labels=labels, predictions=pred_classes)

    # TF Estimators requires to return a EstimatorSpec, that specify
    # the different ops for training, evaluating, ...
    estim_specs = tf.estimator.EstimatorSpec(
        mode=mode,
        predictions=pred_classes,
        loss=loss_op,
        train_op=train_op,
        eval_metric_ops={'accuracy': acc_op})

    return estim_specs

# Build the Estimator
model = tf.estimator.Estimator(model_fn)

# Define the input function for training
input_fn = tf.estimator.inputs.numpy_input_fn(
    x=trainData, y=trainTarget,
    batch_size=batch_size, num_epochs=200, shuffle=True)

# Define the input function for validation
valid_fn = tf.estimator.inputs.numpy_input_fn(
    x=validData, y=validTarget,
    batch_size=batch_size, num_epochs=200, shuffle=True)

# Train the Model
classifier = tf.estimator.Estimator(
    model_fn=model_fn,)

train_spec = tf.estimator.TrainSpec(
    input_fn = input_fn,
)

eval_spec = tf.estimator.EvalSpec(
    input_fn = valid_fn,
    throttle_secs=120,
    start_delay_secs=120,
)

tf.estimator.train_and_evaluate(
    classifier,
    train_spec,
    eval_spec
)


# Evaluate the Model
# Define the input function for evaluating
input_fn = tf.estimator.inputs.numpy_input_fn(
    x=testData, y=testTarget,
    batch_size=batch_size, shuffle=False)
# Use the Estimator 'evaluate' method
e = model.evaluate(input_fn)

print("Testing Accuracy:", e['accuracy'])
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\zorinDM\AppData\Local\Temp\tmpmqaw4cx9
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\zorinDM\\AppData\\Local\\Temp\\tmpmqaw4cx9', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020ECF0C7550>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\zorinDM\AppData\Local\Temp\tmpewga_emh
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\zorinDM\\AppData\\Local\\Temp\\tmpewga_emh', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020ECF0C7438>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\zorinDM\AppData\Local\Temp\tmpewga_emh\model.ckpt.
# INFO:tensorflow:loss = 1.6812678716125122, step = 1
# INFO:tensorflow:global_step/sec: 4.05091
# INFO:tensorflow:loss = 0.12318544677917, step = 101 (24.687 sec)
# INFO:tensorflow:global_step/sec: 4.06487
# INFO:tensorflow:loss = 0.01886870806416253, step = 201 (24.602 sec)
# INFO:tensorflow:global_step/sec: 3.94991
# INFO:tensorflow:loss = 0.003889413644840354, step = 301 (25.316 sec)
# INFO:tensorflow:global_step/sec: 4.04777
# INFO:tensorflow:loss = 0.0018457006020614801, step = 401 (24.706 sec)
# INFO:tensorflow:global_step/sec: 4.24464
# INFO:tensorflow:loss = 0.0016075981215471335, step = 501 (23.559 sec)
# INFO:tensorflow:global_step/sec: 4.06009
# INFO:tensorflow:loss = 0.0008811986586192532, step = 601 (24.631 sec)
# INFO:tensorflow:global_step/sec: 4.51163
# INFO:tensorflow:loss = 0.0004795114357012731, step = 701 (22.163 sec)
# INFO:tensorflow:Saving checkpoints for 747 into C:\Users\zorinDM\AppData\Local\Temp\tmpewga_emh\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-02T09:40:29Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\zorinDM\AppData\Local\Temp\tmpewga_emh\model.ckpt-747
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Finished evaluation at 2019-12-02-09:40:36
# INFO:tensorflow:Saving dict for global step 747: accuracy = 1.0, global_step = 747, loss = 0.0039102486
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 747: C:\Users\zorinDM\AppData\Local\Temp\tmpewga_emh\model.ckpt-747
# INFO:tensorflow:Loss for final step: 0.00021661021217217743.
# INFO:tensorflow:Could not find trained model in model_dir: C:\Users\zorinDM\AppData\Local\Temp\tmpmqaw4cx9, running initialization to evaluate.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-02T09:40:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-02-09:40:37
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.0, global_step = 0, loss = 1.9649615
# Testing Accuracy: 0.0

# %%
names = classifier.get_variable_names()        
print("name:", names)
for i in names:
    print(classifier.get_variable_value(i))
# Out:
# name: ['ConvNet/conv2d/bias', 'ConvNet/conv2d/bias/Adam', 'ConvNet/conv2d/bias/Adam_1', 'ConvNet/conv2d/kernel', 'ConvNet/conv2d/kernel/Adam', 'ConvNet/conv2d/kernel/Adam_1', 'ConvNet/dense/bias', 'ConvNet/dense/bias/Adam', 'ConvNet/dense/bias/Adam_1', 'ConvNet/dense/kernel', 'ConvNet/dense/kernel/Adam', 'ConvNet/dense/kernel/Adam_1', 'ConvNet/dense_1/bias', 'ConvNet/dense_1/bias/Adam', 'ConvNet/dense_1/bias/Adam_1', 'ConvNet/dense_1/kernel', 'ConvNet/dense_1/kernel/Adam', 'ConvNet/dense_1/kernel/Adam_1', 'ConvNet/dense_2/bias', 'ConvNet/dense_2/bias/Adam', 'ConvNet/dense_2/bias/Adam_1', 'ConvNet/dense_2/kernel', 'ConvNet/dense_2/kernel/Adam', 'ConvNet/dense_2/kernel/Adam_1', 'beta1_power', 'beta2_power', 'global_step']
# [-0.01653914  0.01174581 -0.01937437 -0.01404977  0.03002167  0.00675141
#  -0.00435152  0.04276018 -0.02379699  0.00825705 -0.02071043 -0.01100378
#   0.00365066 -0.00938398  0.0017035  -0.01692045  0.00537933  0.03880181
# [-2.44667385e-05  1.67301522e-05  2.54484547e-06  1.13128254e-06
#   1.91462801e-06  2.14583031e-06]
# [1.22349296e-03 1.17343053e-03 2.99785425e-05 5.86092846e-06
#  6.17139167e-06 7.87855103e-06]
# [[-0.11500596  0.08903354  0.04665908 -0.08429217  0.06376322 -0.03006448]
#  [-0.16181681 -0.14072876 -0.04961339  0.08015303  0.14443244 -0.04899828]
#  [ 0.16002759  0.02999686  0.17228439 -0.06661299 -0.01983241 -0.03586433]
#  ...
#  [ 0.03441948  0.00350549  0.04280813 -0.16821052  0.01500498 -0.10250911]
#  [-0.05985265  0.04652358  0.14204505 -0.10353027  0.02729342  0.00315211]
#  [ 0.00841898 -0.12238376 -0.08536557 -0.00392061 -0.03717227  0.14745589]]
# [[ 1.48650317e-04 -1.48124626e-04 -2.26922505e-07  1.17643615e-07
#   -4.42140898e-07  2.57295471e-08]
#  [ 9.27691294e-05 -8.03298643e-05 -5.03477439e-06 -1.35164375e-06
#   -1.60732212e-06 -4.44552486e-06]
#  [-1.07800303e-04  1.07410413e-04  1.88690368e-07 -7.39639545e-08
#    3.10591926e-07 -3.54286036e-08]
#  ...
#  [-1.20313278e-04  1.10041110e-04  3.64677706e-06  1.12200317e-06
#    2.90599007e-06  2.59739833e-06]
#  [ 1.14495787e-04 -1.12309768e-04 -7.29572614e-07 -2.55786026e-07
#   -7.82816995e-07 -4.17843037e-07]
#  [-7.97433878e-05  8.04163410e-05 -2.12877137e-07 -1.92676552e-07
#    1.23508568e-07 -3.90908107e-07]]
# [[3.66220493e-03 3.65455050e-03 6.55684602e-06 9.22408818e-07
#   1.33033038e-06 1.42160033e-06]
#  [2.89340896e-03 2.85275246e-03 1.78524600e-05 3.28737681e-06
#   3.40702009e-06 5.36802616e-06]
#  [2.55623076e-03 2.55004540e-03 1.70290960e-06 3.73894124e-07
#   4.47816438e-07 5.80118294e-07]
#  ...
#  [6.06691616e-04 5.70182642e-04 1.12949502e-05 2.83202640e-06
#   2.30190231e-06 3.60381097e-06]
#  [4.03770979e-04 4.03113875e-04 1.43965221e-06 2.75639155e-07
#   2.92862223e-07 3.86540753e-07]
#  [1.26037870e-03 1.25618588e-03 1.26730047e-06 2.23655906e-07
#   2.29747234e-07 3.28142452e-07]]
# 5.9345567e-35
# 0.4731399
# 747

# %%
weights = classifier.get_variable_value('ConvNet/conv2d/kernel')
print(weights.shape)
a=weights[0][0][0][0:25]
b=a.reshape((5,5))
plt.imshow(b, cmap='gray')
plt.show()

names = ["KERNEL 1", "KERNEL 2", "KERNEL 3", "KERNEL 4"]

fig=plt.figure(figsize=(6, 6))
columns = 2
rows = 2
for i in range(1, columns*rows +1):
    img = trainData[i-1]*255
    ax1 = fig.add_subplot(rows, columns, i)
    ax1.set_title(names[trainTarget[i-1]])
    ax1.get_xaxis().set_visible(False)
    ax1.get_yaxis().set_visible(False)
    a=weights[i][0][0][0:25]
    b=a.reshape((5,5))
    plt.imshow(b, cmap='gray')
    plt.grid
plt.show()
# Out:
# (5, 5, 1, 32)
